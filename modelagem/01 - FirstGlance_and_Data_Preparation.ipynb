# %%
import pandas as pd

# %%
link = 'https://s3-sa-east-1.amazonaws.com/ckan.saude.gov.br/SRAG/2021/INFLUD21-27-09-2021.csv'
df = pd.read_csv(link, sep=";", low_memory=False)

# %%
df.shape
# Out:
# (1508025, 162)

# %%
name='INFLUD21-27-09-2021'

# %%
df.head()
# Out:
#    DT_NOTIFIC  SEM_NOT  DT_SIN_PRI  ...  LOTE_1_COV LOTE_2_COV FNT_IN_COV
# 0  05/01/2021        1  03/01/2021  ...         NaN        NaN        1.0
# 1  07/01/2021        1  04/01/2021  ...         NaN        NaN        NaN
# 2  08/01/2021        1  05/01/2021  ...         NaN        NaN        NaN
# 3  11/01/2021        2  07/01/2021  ...         NaN        NaN        NaN
# 4  09/01/2021        1  07/01/2021  ...         NaN        NaN        NaN
#
# [5 rows x 162 columns]

# %% [markdown]
# # Select the columns to be used:
# #old
# '''columns = ['DT_NOTIFIC',
#         'SEM_NOT',
#         'DT_SIN_PRI',
#         'SEM_PRI',
#         'SG_UF_NOT',
#         'CS_SEXO',
#         'TP_IDADE',
#         'CS_GESTANT',
#         'CS_RACA',
#         'CS_ESCOL_N',
#         'ID_PAIS',
#         'CO_PAIS',
#         'SG_UF',
#         'ID_MN_RESI',
#         'CS_ZONA',
#         'NOSOCOMIAL',
#         'FEBRE',
#         'TOSSE',
#         'GARGANTA',
#         'DISPNEIA',
#         'DESC_RESP',
#         'SATURACAO',
#         'DIARREIA',
#         'VOMITO',
#         'OUTRO_SIN',
#         'OUTRO_DES',
#         'PUERPERA',
#         'FATOR_RISC',
#         'CARDIOPATI',
#         'HEMATOLOGI',
#         'SIND_DOWN',
#         'HEPATICA',
#         'ASMA',
#         'DIABETES',
#         'NEUROLOGIC',
#         'PNEUMOPATI',
#         'IMUNODEPRE',
#         'RENAL',
#         'OBESIDADE',
#         'OBES_IMC',
#         'OUT_MORBI',
#         'MORB_DESC',
#         'VACINA',
#         'DT_UT_DOSE',
#         'MAE_VAC',
#         'DT_VAC_MAE',
#         'ANTIVIRAL',
#         'TP_ANTIVIR',
#         'OUT_ANTIV',
#         'DT_ANTIVIR',
#         'HOSPITAL',
#         'UTI',
#         'DT_ENTUTI',
#         'DT_SAIDUTI',
#         'SUPORT_VEN',
#         'RAIOX_RES',
#         'RAIOX_OUT',
#         'DT_RAIOX',
#         'AMOSTRA',
#         'DT_COLETA',
#         'TP_AMOSTRA',
#         'OUT_AMOST',
#         'PCR_RESUL',
#         'DT_PCR',
#         'POS_PCRFLU',
#         'TP_FLU_PCR',
#         'PCR_FLUASU',
#         'FLUASU_OUT',
#         'PCR_FLUBLI',
#         'FLUBLI_OUT',
#         'POS_PCROUT',
#         'PCR_VSR',
#         'PCR_PARA1',
#         'PCR_PARA2',
#         'PCR_PARA3',
#         'PCR_PARA4',
#         'PCR_ADENO',
#         'PCR_METAP',
#         'PCR_BOCA',
#         'PCR_RINO',
#         'PCR_OUTRO',
#         'DS_PCR_OUT',
#         'CLASSI_FIN',
#         'CLASSI_OUT',
#         'CRITERIO',
#         'EVOLUCAO',
#         'DT_EVOLUCA',
#         'DT_ENCERRA',
#         'PAC_COCBO',
#         'PAC_DSCBO',
#         'DOR_ABD',
#         'FADIGA',
#         'PERD_OLFT',
#         'PERD_PALA',
#         'TOMO_RES',
#         'TOMO_OUT',
#         'DT_TOMO',
#         'TP_TES_AN',
#         'DT_RES_AN',
#         'RES_AN',
#         'POS_AN_FLU',
#         'TP_FLU_AN',
#         'POS_AN_OUT',
#         'AN_SARS2',
#         'AN_VSR',
#         'AN_PARA1',
#         'AN_PARA2',
#         'AN_PARA3',
#         'AN_ADENO',
#         'AN_OUTRO',
#         'DS_AN_OUT',
#         'ESTRANG',
#         'VACINA_COV',
#         'DOSE_1_COV',
#         'DOSE_2_COV',
#         'LAB_PR_COV'
# ]
# df_sub = df[columns]'''

# %%
#Meeting 12/10/2021
#colunas selecionadas pensando que a classificação acontecerá na triagem do paciente.
columns = ['DT_NOTIFIC', #Avaliar a criar uma relacao entre DT_NOTIFIC e DT_SIN_PRI (delta) Numerico
        'DT_SIN_PRI', #Avaliar a criar uma relacao entre DT_NOTIFIC e DT_SIN_PRI (delta)
        'CS_SEXO',
        'CS_GESTANT',
        'CS_RACA',
        'NOSOCOMIAL',
        'FEBRE',
        'TOSSE',
        'GARGANTA',
        'DISPNEIA',
        'DESC_RESP',
        'SATURACAO',
        'DIARREIA',
        'VOMITO',
        'PUERPERA',
        'FATOR_RISC',
        'CARDIOPATI',
        'HEMATOLOGI',
        'SIND_DOWN',
        'HEPATICA',
        'ASMA',
        'DIABETES',
        'NEUROLOGIC',
        'PNEUMOPATI',
        'IMUNODEPRE',
        'RENAL',
        'OBESIDADE',
        'VACINA',
        'ANTIVIRAL',
        #'HOSPITAL', # Retirar pois nao temos esse dado na triagem
        #'UTI', # Retirar pois nao temos esse dado na triagem
        'DT_ENTUTI',  #manter para checagem dos dados
        'DT_SAIDUTI', #manter para checagem dos dados
        'SUPORT_VEN',
        'CLASSI_FIN', # manter para a checagem dos dados
        'CLASSI_OUT', # manter para a checagem dos dados
        'EVOLUCAO', # manter para a checagem dos dados 
        'DOR_ABD',
        'FADIGA',
        'PERD_OLFT',
        'PERD_PALA',
        'VACINA_COV',
        'DOSE_1_COV',
        'DOSE_2_COV'
]
df_sub = df[columns]

# %%
df_sub.shape
# Out:
# (1508025, 42)

# %% [markdown]
# This study has the objective to predict the use or artificial ventilators in patients of acute respiratory syndrome
#
# Column - 'SUPORT_VEN'
#
# This column has the following items:
#
# * 1-Sim, invasivo
# * 2-Sim, não invasivo
# * 3-Não
# * 9-Ignorado
#
# Missing data and values iqual 9 has to be filtered out
# '''

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Filter nan values of column 'SUPORT_VEN'
df_filtered = df_sub[df_sub['SUPORT_VEN'].notnull()]
df_filtered.shape
# Out:
# (1297727, 42)

# %%
df_filtered = df_filtered[df_filtered['SUPORT_VEN']!= 9]
df_filtered.shape
# Out:
# (1255342, 42)

# %%
df_filtered.to_pickle('INFLUD21-27-09-2021-SupportVent_01.pkl')
